# %%
import pandas as pd
import numpy as np
import plotly.express as px
import seaborn as sns
import matplotlib.pyplot as plt
import pickle
# %matplotlib inline

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('./data'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# !gzip -d ./data/RUStoWorldTrade.csv.gz
# Out:
# ./data/RUStoWorldTrade_2012.pkl
# ./data/RUStoWorldTrade_2007.pkl
# ./data/RUStoWorldTrade_2011.pkl
# ./data/RUStoWorldTrade_2008.pkl
# ./data/train_df.parquet
# ./data/RUStoWorldTrade_2010.pkl
# ./data/RUStoWorldTrade_2016.pkl
# ./data/RUStoWorldTrade_2018.pkl
# ./data/RUStoWorldTrade_2019.pkl
# ./data/iso3.csv
# ./data/RUStoWorldTrade_2014.pkl
# ./data/RUStoWorldTrade.csv.gz
# ./data/RUStoWorldTrade_2013.pkl
# ./data/partnerAreas.csv
# ./data/cleaned_data_set.parquet
# ./data/RUStoWorldTrade_2015.pkl
# ./data/RUStoWorldTrade_2009.pkl
# ./data/RUStoWorldTrade_2017.pkl
# ./data/cleaned_data_set_2020.parquet
# ./data/valid_df.parquet
# ./data/RUStoWorldTrade_2020.pkl

# %% [markdown]
# # Load the DF with only the needed columns

# %%
dataframe = pd.read_csv('./data/RUStoWorldTrade.csv',
usecols=['Year','Aggregate Level','Reporter ISO','Partner','Partner ISO','Commodity Code','Commodity','Qty Unit','Qty','Netweight (kg)','Trade Value (US$)'])
dataframe = dataframe.convert_dtypes()
# Out:
# /tmp/ipykernel_62966/3672936799.py:1: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   dataframe = pd.read_csv('./data/RUStoWorldTrade.csv',

# %% [markdown]
# ## <div style="font-family: Trebuchet MS; background-color: #d6604d; color: #FFFFFF; padding: 12px; line-height: 1.5;"> Data pre-processing   📋 </div>
# > Since the data is clean, We need to focus on performance optimization, The Dataset is huge containing 1.3 million data points, Hence it has <span style="background-color: #f09b7a">High memory usage of 650mb</span>,  We'll use the [Starter Code](https://www.kaggle.com/code/pranav941/usage-optimization) provided by the author to optimize performance.  It will convert the data types to smaller ones and help us choosing one of the <span style="background-color: #87beda">five aggregate levels</span>  and  <span style="background-color: #32CD32">reducing the memory usage by 95 % </span>

# %%
dataframe.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1384603 entries, 0 to 1384602
# Data columns (total 11 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   Year               1384603 non-null  Int64
#  1   Aggregate Level    1384603 non-null  Int64
#  2   Reporter ISO       1384603 non-null  string
#  3   Partner            1384603 non-null  string
#  4   Partner ISO        1375914 non-null  string
#  5   Commodity Code     1384603 non-null  object
#  6   Commodity          1384603 non-null  string
#  7   Qty Unit           1384603 non-null  string
#  8   Qty                1283894 non-null  Int64
#  9   Netweight (kg)     1323567 non-null  Int64
#  10  Trade Value (US$)  1384603 non-null  Int64
# dtypes: Int64(5), object(1), string(5)
# memory usage: 638.8 MB

# %%
dataframe
# Out:
#          Year  Aggregate Level Reporter ISO      Partner Partner ISO  \
# 0        2011                1          RUS  Cayman Isds         CYM
# 1        2012                1          RUS  Cayman Isds         CYM
# 2        2015                1          RUS  Cayman Isds         CYM
# 3        2016                1          RUS  Cayman Isds         CYM
# 4        2017                1          RUS  Cayman Isds         CYM
# ...       ...              ...          ...          ...         ...
# 1384598  2017                1          RUS     Zimbabwe         ZWE
# 1384599  2018                1          RUS     Zimbabwe         ZWE
# 1384600  2019                1          RUS     Zimbabwe         ZWE
# 1384601  2020                1          RUS     Zimbabwe         ZWE
# 1384602  2020                1          RUS     Zimbabwe         ZWE
#
#         Commodity Code                                          Commodity  \
# 0                    6  Manufactured goods classified chiefly by material
# 1                    6  Manufactured goods classified chiefly by material
# 2                    6  Manufactured goods classified chiefly by material
# 3                    6  Manufactured goods classified chiefly by material
# 4                    6  Manufactured goods classified chiefly by material
# ...                ...                                                ...
# 1384598              8                Miscellaneous manufactured articles
# 1384599              8                Miscellaneous manufactured articles
# 1384600              8                Miscellaneous manufactured articles
# 1384601              8                Miscellaneous manufactured articles
# 1384602              9  Commodities and transactions not classified el...
#
#             Qty Unit   Qty  Netweight (kg)  Trade Value (US$)
# 0        No Quantity  <NA>            <NA>              75591
# 1        No Quantity  <NA>            <NA>              27778
# 2        No Quantity  <NA>            <NA>            2131579
# 3        No Quantity     0               0            9055543
# 4        No Quantity     0               0           19952598
# ...              ...   ...             ...                ...
# 1384598  No Quantity     0               0            1339699
# 1384599  No Quantity     0               0             838057
# 1384600  No Quantity     0               0             812152
# 1384601  No Quantity     0               0              43484
# 1384602  No Quantity     0               0              60323
#
# [1384603 rows x 11 columns]

# %%
for col in dataframe.columns:
    if dataframe[col].dtype == 'Float64':
        dataframe[col] = dataframe[col].astype('float16')
    try : 
        if dataframe[col].dtype == 'Int64':
            dataframe[col] = dataframe[col].astype('int16')
    except :
        dataframe[col] = dataframe[col].astype('float16')
dataframe.drop(dataframe[dataframe['Commodity Code'] == 'TOTAL'].index, inplace=True)
dataframe['Commodity Code'] = dataframe['Commodity Code'].astype('float16')

# %% [markdown]
# # Add sub-continent

# %%
df = dataframe[dataframe['Aggregate Level']==2]
iso = pd.read_csv('./data/iso3.csv')
iso.drop(axis=1, columns=['FIPS','ISO (2)','ISO (No)','Internet','Note','Capital'], inplace=True)

continents = ['Asia', 'Europe', 'Africa', 'Oceania', 'Americas']
for x in continents:        
    y = iso[iso['Continent'] == x]
    m = df['Partner ISO'].isin(y['ISO (3)'])
    df.loc[m, 'Continent'] = x

Region = ['South Asia', 'South East Europe', 'Northern Africa', 'Pacific',
       'South West Europe', 'Southern Africa', 'West Indies',
       'South America', 'South West Asia', 'Central Europe',
       'Eastern Europe', 'Western Europe', 'Central America',
       'Western Africa', 'South East Asia', 'Central Africa',
       'North America', 'East Asia', 'Indian Ocean', 'Northern Europe',
       'Eastern Africa', 'Southern Europe', 'Central Asia',
       'Northern Asia']

for x in Region:        
    y = iso[iso['Region'] == x]
    m = df['Partner ISO'].isin(y['ISO (3)'])
    df.loc[m, 'Region'] = x
# Out:
# /tmp/ipykernel_62966/3113330564.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[m, 'Continent'] = x
# /tmp/ipykernel_62966/3113330564.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[m, 'Region'] = x

# %%
df.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 79030 entries, 11 to 1384534
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Year               79030 non-null  int16
#  1   Aggregate Level    79030 non-null  int16
#  2   Reporter ISO       79030 non-null  string
#  3   Partner            79030 non-null  string
#  4   Partner ISO        78318 non-null  string
#  5   Commodity Code     79030 non-null  float16
#  6   Commodity          79030 non-null  string
#  7   Qty Unit           79030 non-null  string
#  8   Qty                31621 non-null  float16
#  9   Netweight (kg)     31556 non-null  float16
#  10  Trade Value (US$)  79030 non-null  int16
#  11  Continent          74838 non-null  object
#  12  Region             74838 non-null  object
# dtypes: float16(3), int16(3), object(2), string(5)
# memory usage: 38.5 MB

# %%
df
# Out:
#          Year  Aggregate Level Reporter ISO      Partner Partner ISO  \
# 11       2011                2          RUS  Cayman Isds         CYM
# 12       2012                2          RUS  Cayman Isds         CYM
# 13       2014                2          RUS  Cayman Isds         CYM
# 14       2015                2          RUS  Cayman Isds         CYM
# 15       2016                2          RUS  Cayman Isds         CYM
# ...       ...              ...          ...          ...         ...
# 1384530  2020                2          RUS     Zimbabwe         ZWE
# 1384531  2020                2          RUS     Zimbabwe         ZWE
# 1384532  2020                2          RUS     Zimbabwe         ZWE
# 1384533  2020                2          RUS     Zimbabwe         ZWE
# 1384534  2020                2          RUS     Zimbabwe         ZWE
#
#          Commodity Code                                          Commodity  \
# 11                 65.0  Textile yarn, fabrics, made-up articles, n.e.s...
# 12                 65.0  Textile yarn, fabrics, made-up articles, n.e.s...
# 13                 89.0        Miscellaneous manufactured articles, n.e.s.
# 14                 68.0                                 Non-ferrous metals
# 15                 68.0                                 Non-ferrous metals
# ...                 ...                                                ...
# 1384530            77.0  Electrical machinery, apparatus and appliances...
# 1384531            87.0  Professional, scientific and controlling instr...
# 1384532            88.0  Photographic apparatus, equipment and supplies...
# 1384533            89.0        Miscellaneous manufactured articles, n.e.s.
# 1384534            93.0  Special transactions and commodities not class...
#
#             Qty Unit  Qty  Netweight (kg)  Trade Value (US$) Continent  \
# 11       No Quantity  NaN             NaN              10055  Americas
# 12       No Quantity  NaN             NaN              27778  Americas
# 13       No Quantity  NaN             NaN              16098  Americas
# 14       No Quantity  NaN             NaN             -31109  Americas
# 15       No Quantity  0.0             0.0              11575  Americas
# ...              ...  ...             ...                ...       ...
# 1384530  No Quantity  0.0             0.0                976    Africa
# 1384531  No Quantity  0.0             0.0             -27292    Africa
# 1384532  No Quantity  0.0             0.0                361    Africa
# 1384533  No Quantity  0.0             0.0               4877    Africa
# 1384534  No Quantity  0.0             0.0              -5213    Africa
#
#                   Region
# 11           West Indies
# 12           West Indies
# 13           West Indies
# 14           West Indies
# 15           West Indies
# ...                  ...
# 1384530  Southern Africa
# 1384531  Southern Africa
# 1384532  Southern Africa
# 1384533  Southern Africa
# 1384534  Southern Africa
#
# [79030 rows x 13 columns]

# %%
from sklearn.feature_extraction import DictVectorizer
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge

from sklearn.metrics import mean_squared_error

# %% [markdown]
# # Create DF per year to have enough train and test data

# %%
# Find all the years
years = df[['Year']]
years = years.drop_duplicates(subset=['Year']).sort_values(by=['Year'])['Year'].to_numpy()
print(years)
for year in years:
  print(year)
# Out:
# [2007 2008 2009 2010 2011 2012 2013 2014 2015 2016 2017 2018 2019 2020]
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2018
# 2019
# 2020

# %%
df[df['Year'] == 2008]
# Out:
#          Year  Aggregate Level Reporter ISO               Partner Partner ISO  \
# 97       2008                2          RUS  Central African Rep.         CAF
# 98       2008                2          RUS  Central African Rep.         CAF
# 1397     2008                2          RUS                  Chad         TCD
# 1398     2008                2          RUS                  Chad         TCD
# 1399     2008                2          RUS                  Chad         TCD
# ...       ...              ...          ...                   ...         ...
# 1384395  2008                2          RUS              Zimbabwe         ZWE
# 1384396  2008                2          RUS              Zimbabwe         ZWE
# 1384397  2008                2          RUS              Zimbabwe         ZWE
# 1384398  2008                2          RUS              Zimbabwe         ZWE
# 1384399  2008                2          RUS              Zimbabwe         ZWE
#
#          Commodity Code                                          Commodity  \
# 97                 74.0  General industrial machinery and equipment, n....
# 98                 78.0     Road vehicles (including air-cushion vehicles)
# 1397               33.0  Petroleum, petroleum products and related mate...
# 1398               58.0                      Plastics in non-primary forms
# 1399               59.0            Chemical materials and products, n.e.s.
# ...                 ...                                                ...
# 1384395            73.0                             Metalworking machinery
# 1384396            74.0  General industrial machinery and equipment, n....
# 1384397            77.0  Electrical machinery, apparatus and appliances...
# 1384398            87.0  Professional, scientific and controlling instr...
# 1384399            89.0        Miscellaneous manufactured articles, n.e.s.
#
#             Qty Unit  Qty  Netweight (kg)  Trade Value (US$) Continent  \
# 97       No Quantity  NaN             NaN               4420    Africa
# 98       No Quantity  NaN             NaN              15185    Africa
# 1397     No Quantity  NaN             NaN               5810    Africa
# 1398     No Quantity  NaN             NaN                774    Africa
# 1399     No Quantity  NaN             NaN              11450    Africa
# ...              ...  ...             ...                ...       ...
# 1384395  No Quantity  NaN             NaN              10310    Africa
# 1384396  No Quantity  NaN             NaN               6376    Africa
# 1384397  No Quantity  NaN             NaN               4166    Africa
# 1384398  No Quantity  NaN             NaN                207    Africa
# 1384399  No Quantity  NaN             NaN                296    Africa
#
#                   Region
# 97        Central Africa
# 98        Central Africa
# 1397      Central Africa
# 1398      Central Africa
# 1399      Central Africa
# ...                  ...
# 1384395  Southern Africa
# 1384396  Southern Africa
# 1384397  Southern Africa
# 1384398  Southern Africa
# 1384399  Southern Africa
#
# [4904 rows x 13 columns]

# %%
def save_dataset_per_year(df, year):
  df = df[df['Year'] == year]
  df.to_pickle('./data/RUStoWorldTrade_' + str(year) + '.pkl')

def read_dataset(year):
  df = pd.read_pickle('./data/RUStoWorldTrade_' + str(year) + '.pkl')
  return df

# %%
for year in years:
  save_dataset_per_year(df, year)

# %% [markdown]
# # Let's train on year 2007-2015 and use the other data as test data

# %%
categorical = ['Partner ISO', 'Commodity Code']
numerical = ['Year']

# %%
df[df['Partner ISO'] == 'NaN']
# Out:
# Empty DataFrame
# Columns: [Year, Aggregate Level, Reporter ISO, Partner, Partner ISO, Commodity Code, Commodity, Qty Unit, Qty, Netweight (kg), Trade Value (US$), Continent, Region]
# Index: []

# %%
def save_to_parquet(df, filename):
  half_floats = df.select_dtypes(include="float16")
  df[half_floats.columns] = half_floats.astype("float32")
  df.to_parquet(filename)
  
def read_parquet(filename):
  df = pd.read_parquet(filename)
  return df

def save_model(file, dv, lr):
  with open(file, 'wb') as f_out:
    pickle.dump((dv, lr), f_out)

# %%
save_to_parquet(df, "./data/cleaned_data_set.parquet")
# Out:
# /tmp/ipykernel_62966/604317711.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[half_floats.columns] = half_floats.astype("float32")

# %%
# print(X_train.shape, y_train.shape)
# print(X_val.shape, y_val.shape)



# #X_val.reshape(31621, 270)
# print(X_val.shape, y_val.shape)

# print(df_train.info())
# print(len(train_dicts),len(valid_dicts))
# print(len(valid_dicts),len(valid_dicts))

# %%
#print(df_valid.info())

# %%
#df_valid.iloc[:, :279]

# %%
#res = len([ele for ele in train_dicts if isinstance(ele, dict)])
  
# printing result 
#print("The Dictionary count : " + str(res))

# %%
train_years = [2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014]
df_train = df.loc[(df['Year']>=2007) & (df['Year']<=2015)]
df_valid = df.loc[(df['Year']>=2016) & (df['Year']<=2020)] 

#df = read_dataset(2008) - 
# I must convert to str otherwise the DV fail. Explain why?

dv = DictVectorizer()
target = 'Trade Value (US$)'

# Prepare train data
df_train[categorical] = df_train[categorical].astype(str)
train_dicts = df_train[categorical + numerical].to_dict(orient='records')
X_train = dv.fit_transform(train_dicts)
y_train = df_train[target].values 

# Prepare validation data
df_valid[categorical] = df_valid[categorical].astype(str)
valid_dicts = df_valid[categorical + numerical].to_dict(orient='records')
X_val = dv.transform(valid_dicts)
y_val = df_valid[target].values 

lr = LinearRegression()
lr.fit(X_train, y_train)

y_pred = lr.predict(X_val)

mean_squared_error(y_val, y_pred, squared=False)
# Out:
# /tmp/ipykernel_62966/260211561.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train[categorical] = df_train[categorical].astype(str)
# /tmp/ipykernel_62966/260211561.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_valid[categorical] = df_valid[categorical].astype(str)
# 17550.69177329031

# %%
print(categorical + numerical)
features_dict = [ {"Partner ISO": "ZWE", "Commodity Code": "68.0", "Year": 2018} ]
features = dv.transform(features_dict)
print(features)
test_prediction = lr.predict(features)
print(test_prediction)
# Out:
# ['Partner ISO', 'Commodity Code', 'Year']
#   (0, 41)	1.0
#   (0, 281)	1.0
#   (0, 282)	2018.0
# [710.76765203]

# %%
save_model('models/lin_reg.bin', dv, lr)

# %%
save_to_parquet(df_train, "./data/train_df.parquet")
save_to_parquet(df_valid, "./data/valid_df.parquet")

# %%
sns.distplot(y_pred, label='prediction')
sns.distplot(y_train, label='actual')

plt.legend()
# Out:
# /home/asurace/.local/share/virtualenvs/07-project-bZg0EPfU/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/asurace/.local/share/virtualenvs/07-project-bZg0EPfU/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# # Create a ML pipeline

# %%
import mlflow

mlflow.set_tracking_uri("sqlite:///mlflow.db")
mlflow.set_experiment("russiaWorldTrade")
# Out:
# 2022/09/02 00:12:16 INFO mlflow.tracking.fluent: Experiment with name 'russiaWorldTrade' does not exist. Creating a new experiment.
# <Experiment: artifact_location='./mlruns/1', experiment_id='1', lifecycle_stage='active', name='russiaWorldTrade', tags={}>

# %%
df_train = read_parquet('./data/train_df.parquet')
df_valid = read_parquet('./data/valid_df.parquet')

# %%
df_valid
# Out:
#          Year  Aggregate Level Reporter ISO      Partner Partner ISO  \
# 15       2016                2          RUS  Cayman Isds         CYM
# 16       2017                2          RUS  Cayman Isds         CYM
# 17       2017                2          RUS  Cayman Isds         CYM
# 18       2018                2          RUS  Cayman Isds         CYM
# 19       2018                2          RUS  Cayman Isds         CYM
# ...       ...              ...          ...          ...         ...
# 1384530  2020                2          RUS     Zimbabwe         ZWE
# 1384531  2020                2          RUS     Zimbabwe         ZWE
# 1384532  2020                2          RUS     Zimbabwe         ZWE
# 1384533  2020                2          RUS     Zimbabwe         ZWE
# 1384534  2020                2          RUS     Zimbabwe         ZWE
#
#         Commodity Code                                          Commodity  \
# 15                68.0                                 Non-ferrous metals
# 16                68.0                                 Non-ferrous metals
# 17                89.0        Miscellaneous manufactured articles, n.e.s.
# 18                68.0                                 Non-ferrous metals
# 19                89.0        Miscellaneous manufactured articles, n.e.s.
# ...                ...                                                ...
# 1384530           77.0  Electrical machinery, apparatus and appliances...
# 1384531           87.0  Professional, scientific and controlling instr...
# 1384532           88.0  Photographic apparatus, equipment and supplies...
# 1384533           89.0        Miscellaneous manufactured articles, n.e.s.
# 1384534           93.0  Special transactions and commodities not class...
#
#             Qty Unit  Qty  Netweight (kg)  Trade Value (US$) Continent  \
# 15       No Quantity  0.0             0.0              11575  Americas
# 16       No Quantity  0.0             0.0              29654  Americas
# 17       No Quantity  0.0             0.0               5398  Americas
# 18       No Quantity  0.0             0.0             -21365  Americas
# 19       No Quantity  0.0             0.0               1279  Americas
# ...              ...  ...             ...                ...       ...
# 1384530  No Quantity  0.0             0.0                976    Africa
# 1384531  No Quantity  0.0             0.0             -27292    Africa
# 1384532  No Quantity  0.0             0.0                361    Africa
# 1384533  No Quantity  0.0             0.0               4877    Africa
# 1384534  No Quantity  0.0             0.0              -5213    Africa
#
#                   Region
# 15           West Indies
# 16           West Indies
# 17           West Indies
# 18           West Indies
# 19           West Indies
# ...                  ...
# 1384530  Southern Africa
# 1384531  Southern Africa
# 1384532  Southern Africa
# 1384533  Southern Africa
# 1384534  Southern Africa
#
# [31621 rows x 13 columns]

# %%
with mlflow.start_run():

    mlflow.set_tag("developer", "Alessandro")

    mlflow.log_param("train-data-path", "./data/train_df.parquet")
    mlflow.log_param("valid-data-path", "./data/valid_df.parquet")


    alpha = 0.1
    mlflow.log_param("alpha", alpha)
    lr = Lasso(alpha)
    lr.fit(X_train, y_train)

    y_pred = lr.predict(X_val)
    rmse = mean_squared_error(y_val, y_pred, squared=False)
    mlflow.log_metric("rmse", rmse)

    mlflow.log_artifact(local_path="models/lin_reg.bin", artifact_path="models_pickle")
    # with mlflow 1.28.0 MlflowException: The configured tracking uri scheme: 'sqlite' is invalid for use with the proxy mlflow-artifact scheme. The allowed tracking schemes are: {'https', 'http'}
    # mlflow db update
    # mlflow db upgrade sqlite:///mlflow.db

# %%
import xgboost as xgb
# Method to find the best hyperparams
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
from hyperopt.pyll import scope

# %%
train = xgb.DMatrix(X_train, label=y_train)
valid = xgb.DMatrix(X_val, label=y_val)

# %%
def objective(params):
  with mlflow.start_run():

    mlflow.set_tag("developer", "Alessandro")
    mlflow.set_tag("model", "xgboost")
    # mlflow.log_params(params) # Using mlflow.xgboost.autolog() later
    # mlflow.log_param("train-data-path", "./data/train_df.parquet")
    # mlflow.log_param("valid-data-path", "./data/valid_df.parquet")

    booster = xgb.train(
            params=params,
            dtrain=train,
            num_boost_round=1000,
            evals=[(valid, 'validation')],
            early_stopping_rounds=50
        )

    y_pred = booster.predict(valid)
    rmse = mean_squared_error(y_val, y_pred, squared=False)
    mlflow.log_metric("rmse", rmse)
    mlflow.log_artifact(local_path="models/lin_reg.bin", artifact_path="models_pickle")
    
    return {'loss': rmse, 'status': STATUS_OK}
        
    # #alpha = 0.1
    # mlflow.log_param("alpha", alpha)
    # lr = Lasso(alpha)
    # lr.fit(X_train, y_train)

    # y_pred = lr.predict(X_val)
    # rmse = mean_squared_error(y_val, y_pred, squared=False)
    # mlflow.log_metric("rmse", rmse)

# %%
# See http://hyperopt.github.io/hyperopt/getting-started/search_spaces/ 
search_space = {
    'max_depth': scope.int(hp.quniform('max_depth', 4, 100, 1)),
    'learning_rate': hp.loguniform('learning_rate', -3, 0), # exp(-3), exp(0) - [0.05 -1]
    'reg_alpha': hp.loguniform('reg_alpha', -5, -1),
    'reg_lambda': hp.loguniform('reg_lambda', -6, -1),
    'min_child_weight': hp.loguniform('min_child_weight', -1, 3),
    'objective': 'reg:linear',
    'seed': 42
}

mlflow.xgboost.autolog()

best_result = fmin(
    fn=objective,
    space=search_space,
    algo=tpe.suggest,
    max_evals=50,
    trials=Trials()
)
# Out:
# 2022/09/02 00:17:16 WARNING mlflow.utils.autologging_utils: You are using an unsupported version of xgboost. If you encounter errors during autologging, try upgrading / downgrading xgboost to a supported version, or try upgrading MLflow.
# [00:17:16] WARNING: ../src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:17541.62551
# [1]	validation-rmse:17542.30488
# [2]	validation-rmse:17550.83628
# [3]	validation-rmse:17558.97114
# [4]	validation-rmse:17570.60440
# [5]	validation-rmse:17585.50230
# [6]	validation-rmse:17601.46159
# [7]	validation-rmse:17617.95783
# [8]	validation-rmse:17633.62039
# [9]	validation-rmse:17650.86309
# [10]	validation-rmse:17662.31638
# [11]	validation-rmse:17676.81587
# [12]	validation-rmse:17694.53486
# [13]	validation-rmse:17709.51096
# [14]	validation-rmse:17722.93272
# [15]	validation-rmse:17736.22888
# [16]	validation-rmse:17753.46009
# [17]	validation-rmse:17767.21511
# [18]	validation-rmse:17781.98836
# [19]	validation-rmse:17793.82109
# [20]	validation-rmse:17802.85528
# [21]	validation-rmse:17817.31301
# [22]	validation-rmse:17830.11506
# [23]	validation-rmse:17842.44019
# [24]	validation-rmse:17854.15557
# [25]	validation-rmse:17862.08665
# [26]	validation-rmse:17877.48571
# [27]	validation-rmse:17893.15937
# [28]	validation-rmse:17909.30323
# [29]	validation-rmse:17923.86650
# [30]	validation-rmse:17934.27429
# [31]	validation-rmse:17950.71057
# [32]	validation-rmse:17970.59093
# [33]	validation-rmse:17978.72033
# [34]	validation-rmse:17991.94015
# [35]	validation-rmse:18004.82924
# [36]	validation-rmse:18018.06145
# [37]	validation-rmse:18028.34238
# [38]	validation-rmse:18038.74784
# [39]	validation-rmse:18049.58965
# [40]	validation-rmse:18065.20572
# [41]	validation-rmse:18075.81246
# [42]	validation-rmse:18092.48057
# [43]	validation-rmse:18105.09407
# [44]	validation-rmse:18112.95529
# [45]	validation-rmse:18125.21624
# [46]	validation-rmse:18132.13605
# [47]	validation-rmse:18142.94055
# [48]	validation-rmse:18154.66387
# [49]	validation-rmse:18172.63512
#   0%|          | 0/50 [00:45<?, ?trial/s, best loss=?]
# 2022/09/02 00:18:03 WARNING mlflow.xgboost: Failed to infer model signature: could not sample data to infer model signature: please ensure that autologging is enabled before constructing the dataset.
#
# 2022/09/02 00:18:05 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/home/asurace/.local/share/virtualenvs/07-project-bZg0EPfU/lib/python3.9/site-packages/_distutils_hack/__init__.py:33: UserWarning: Setuptools is replacing distutils."
# [00:18:05] WARNING: ../src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:17675.05622
# [1]	validation-rmse:17800.34068
# [2]	validation-rmse:17884.77187
# [3]	validation-rmse:17997.23561
# [4]	validation-rmse:18043.74978
# [5]	validation-rmse:18101.97348
# [6]	validation-rmse:18162.81603
# [7]	validation-rmse:18249.01701
# [8]	validation-rmse:18292.33233
# [9]	validation-rmse:18346.25833
# [10]	validation-rmse:18389.26179
# [11]	validation-rmse:18422.00176
# [12]	validation-rmse:18452.57884
# [13]	validation-rmse:18492.83273
# [14]	validation-rmse:18512.46789
# [15]	validation-rmse:18544.66425
# [16]	validation-rmse:18576.90111
# [17]	validation-rmse:18595.55864
# [18]	validation-rmse:18624.26163
WARNING mlflow.xgboost: Failed to infer model signature: could not sample data to infer model signature: please ensure that autologging is enabled before constructing the dataset.
# [00:52:59] WARNING: ../src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:17714.48614
# [1]	validation-rmse:17933.65533
# [2]	validation-rmse:18126.05140
# [3]	validation-rmse:18260.45663
# [4]	validation-rmse:18483.51313
# [5]	validation-rmse:18623.93813
# [6]	validation-rmse:18738.40387
# [7]	validation-rmse:18858.31720
# [8]	validation-rmse:19031.76432
# [9]	validation-rmse:19157.63859
# [10]	validation-rmse:19291.10145
# [11]	validation-rmse:19352.90848
# [12]	validation-rmse:19425.18024
# [13]	validation-rmse:19524.00348
# [14]	validation-rmse:19642.60784
# [15]	validation-rmse:19656.21951
# [16]	validation-rmse:19735.94996
# [17]	validation-rmse:19806.55402
# [18]	validation-rmse:19894.71793
# [19]	validation-rmse:19942.34928
# [20]	validation-rmse:19996.66313
# [21]	validation-rmse:20049.80702
# [22]	validation-rmse:20113.04771
# [23]	validation-rmse:20153.63628
# [24]	validation-rmse:20174.17417
# [25]	validation-rmse:20233.43533
# [26]	validation-rmse:20274.45937
# [27]	validation-rmse:20316.35370
# [28]	validation-rmse:20321.57435
# [29]	validation-rmse:20358.99201
# [30]	validation-rmse:20387.30005
# [31]	validation-rmse:20428.28192
# [32]	validation-rmse:20447.43316
# [33]	validation-rmse:20468.20444
# [34]	validation-rmse:20511.38278
# [35]	validation-rmse:20524.22245
# [36]	validation-rmse:20540.76041
# [37]	validation-rmse:20578.19869
# [38]	validation-rmse:20615.46407
# [39]	validation-rmse:20638.04173
# [40]	validation-rmse:20667.60145
# [41]	validation-rmse:20697.61233
# [42]	validation-rmse:20769.05569
# [43]	validation-rmse:20803.69287
# [44]	validation-rmse:20816.10562
# [45]	validation-rmse:20841.63446
# [46]	validation-rmse:20863.48595
# [47]	validation-rmse:20877.79413
# [48]	validation-rmse:20895.09427
# [49]	validation-rmse:20947.10325
# [50]	validation-rmse:20966.53449
#  98%|█████████▊| 49/50 [36:45<00:56, 56.63s/trial, best loss: 17518.595703125]
# 2022/09/02 00:54:03 WARNING mlflow.xgboost: Failed to infer model signature: could not sample data to infer model signature: please ensure that autologging is enabled before constructing the dataset.
# 100%|██████████| 50/50 [36:47<00:00, 44.16s/trial, best loss: 17518.595703125]

# %%
# example of hyperopt-sklearn for the housing regression dataset
from pandas import read_csv
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from hpsklearn import HyperoptEstimator
from hpsklearn import any_regressor
from hpsklearn import any_preprocessing
from hyperopt import tpe
# load dataset
url = 'https://raw.githubusercontent.com/jbrownlee/Datasets/master/housing.csv'
dataframe = read_csv(url, header=None)
# split into input and output elements
data = dataframe.values
data = data.astype('float32')
X, y = data[:, :-1], data[:, -1]
# split into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=1)
# define search
model = HyperoptEstimator(regressor=any_regressor('reg'), preprocessing=any_preprocessing('pre'), loss_fn=mean_absolute_error, algo=tpe.suggest, max_evals=50, trial_timeout=30)
# perform the search
model.fit(X_train, y_train)
# summarize performance
mae = model.score(X_test, y_test)
print("MAE: %.3f" % mae)
# summarize the best model
print(model.best_model())
# Out:
# WARN: OMP_NUM_THREADS=None =>
# ... If you are using openblas if you are using openblas set OMP_NUM_THREADS=1 or risk subprocess calls hanging indefinitely
#   0%|          | 0/1 [00:00<?, ?trial/s, best loss=?]
# 2022/09/02 01:12:42 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'a5c14c12ecf54b7a9387033602df9fa9', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# 100%|██████████| 1/1 [00:30<00:00, 30.09s/trial, best loss=?]
# ---------------------------------------------------------------------------
# AllTrialsFailed                           Traceback (most recent call last)
# /home/asurace/github/mlops-zoomcamp/07-project/ml_training_fit.ipynb Cell 42 in <cell line: 21>()
#      <a href='vscode-notebook-cell:/home/asurace/github/mlops-zoomcamp/07-project/ml_training_fit.ipynb#X56sZmlsZQ%3D%3D?line=18'>19</a> model = HyperoptEstimator(regressor=any_regressor('reg'), preprocessing=any_preprocessing('pre'), loss_fn=mean_absolute_error, algo=tpe.suggest, max_evals=50, trial_timeout=30)
#      <a href='vscode-notebook-cell:/home/asurace/github/mlops-zoomcamp/07-project/ml_training_fit.ipynb#X56sZmlsZQ%3D%3D?line=19'>20</a> # perform the search
# ---> <a href='vscode-notebook-cell:/home/asurace/github/mlops-zoomcamp/07-project/ml_training_fit.ipynb#X56sZmlsZQ%3D%3D?line=20'>21</a> model.fit(X_train, y_train)
#      <a href='vscode-notebook-cell:/home/asurace/github/mlops-zoomcamp/07-project/ml_training_fit.ipynb#X56sZmlsZQ%3D%3D?line=21'>22</a> # summarize performance
#      <a href='vscode-notebook-cell:/home/asurace/github/mlops-zoomcamp/07-project/ml_training_fit.ipynb#X56sZmlsZQ%3D%3D?line=22'>23</a> mae = model.score(X_test, y_test)
#
# File ~/.local/share/virtualenvs/07-project-bZg0EPfU/lib/python3.9/site-packages/hpsklearn/estimator.py:783, in hyperopt_estimator.fit(self, X, y, EX_list, valid_size, n_folds, cv_shuffle, warm_start, random_state, weights)
#     780 try:
#     781     increment = min(self.fit_increment,
#     782                     adjusted_max_evals - len(self.trials.trials))
# --> 783     fit_iter.send(increment)
#     784     if filename is not None:
#     785         with open(filename, 'wb') as dump_file:
#
# File ~/.local/share/virtualenvs/07-project-bZg0EPfU/lib/python3.9/site-packages/hpsklearn/estimator.py:684, in hyperopt_estimator.fit_iter(self, X, y, EX_list, valid_size, n_folds, cv_shuffle, warm_start, random_state, weights, increment)
#     681 #FIXME: temporary workaround for rstate issue #35
#     682 #       latest hyperopt.fmin() on master does not match PyPI
#     683 if 'rstate' in inspect.getargspec(hyperopt.fmin).args:
# --> 684     hyperopt.fmin(fn_with_timeout,
#     685                   space=self.space,
#     686                   algo=self.algo,
#     687                   trials=self.trials,
#     688                   max_evals=len(self.trials.trials) + increment,
#     689                   rstate=self.rstate,
#     690                   # -- let exceptions crash the program,
#     691                   #    so we notice them.
#     692                   catch_eval_exceptions=False,
#     693                   return_argmin=False, # -- in case no success so far
#     694                  )
#     695 else:
#     696     if self.seed is None:
#
# File ~/.local/share/virtualenvs/07-project-bZg0EPfU/lib/python3.9/site-packages/hyperopt/fmin.py:507, in fmin(fn, space, algo, max_evals, timeout, loss_threshold, trials, rstate, allow_trials_fmin, pass_expr_memo_ctrl, catch_eval_exceptions, verbose, return_argmin, points_to_evaluate, max_queue_len, show_progressbar, early_stop_fn, trials_save_file)
#     504 validate_loss_threshold(loss_threshold)
#     506 if allow_trials_fmin and hasattr(trials, "fmin"):
# --> 507     return trials.fmin(
#     508         fn,
#     509         space,
#     510         algo=algo,
#     511         max_evals=max_evals,
#     512         timeout=timeout,
#     513         loss_threshold=loss_threshold,
#     514         max_queue_len=max_queue_len,
#     515         rstate=rstate,
#     516         pass_expr_memo_ctrl=pass_expr_memo_ctrl,
#     517         verbose=verbose,
#     518         catch_eval_exceptions=catch_eval_exceptions,
#     519         return_argmin=return_argmin,
#     520         show_progressbar=show_progressbar,
#     521         early_stop_fn=early_stop_fn,
#     522         trials_save_file=trials_save_file,
#     523     )
#     525 if trials is None:
#     526     if os.path.exists(trials_save_file):
#
# File ~/.local/share/virtualenvs/07-project-bZg0EPfU/lib/python3.9/site-packages/hyperopt/base.py:682, in Trials.fmin(self, fn, space, algo, max_evals, timeout, loss_threshold, max_queue_len, rstate, verbose, pass_expr_memo_ctrl, catch_eval_exceptions, return_argmin, show_progressbar, early_stop_fn, trials_save_file)
#     677 # -- Stop-gap implementation!
#     678 #    fmin should have been a Trials method in the first place
#     679 #    but for now it's still sitting in another file.
#     680 from .fmin import fmin
# --> 682 return fmin(
#     683     fn,
#     684     space,
#     685     algo,
#     686     max_evals,
#     687     timeout=timeout,
#     688     loss_threshold=loss_threshold,
#     689     trials=self,
#     690     rstate=rstate,
#     691     verbose=verbose,
#     692     max_queue_len=max_queue_len,
#     693     allow_trials_fmin=False,  # -- prevent recursion
#     694     pass_expr_memo_ctrl=pass_expr_memo_ctrl,
#     695     catch_eval_exceptions=catch_eval_exceptions,
#     696     return_argmin=return_argmin,
#     697     show_progressbar=show_progressbar,
#     698     early_stop_fn=early_stop_fn,
#     699     trials_save_file=trials_save_file,
#     700 )
#
# File ~/.local/share/virtualenvs/07-project-bZg0EPfU/lib/python3.9/site-packages/hyperopt/fmin.py:564, in fmin(fn, space, algo, max_evals, timeout, loss_threshold, trials, rstate, allow_trials_fmin, pass_expr_memo_ctrl, catch_eval_exceptions, verbose, return_argmin, points_to_evaluate, max_queue_len, show_progressbar, early_stop_fn, trials_save_file)
#     560     return trials.argmin
#     561 if len(trials) > 0:
#     562     # Only if there are some successful trail runs, return the best point in
#     563     # the evaluation space
# --> 564     return space_eval(space, trials.argmin)
#     565 return None
#
# File ~/.local/share/virtualenvs/07-project-bZg0EPfU/lib/python3.9/site-packages/hyperopt/base.py:631, in Trials.argmin(self)
#     629 @property
#     630 def argmin(self):
# --> 631     best_trial = self.best_trial
#     632     vals = best_trial["misc"]["vals"]
#     633     # unpack the one-element lists to values
#     634     # and skip over the 0-element lists
#
# File ~/.local/share/virtualenvs/07-project-bZg0EPfU/lib/python3.9/site-packages/hyperopt/base.py:622, in Trials.best_trial(self)
#     616 candidates = [
#     617     t
#     618     for t in self.trials
#     619     if t["result"]["status"] == STATUS_OK and not np.isnan(t["result"]["loss"])
#     620 ]
#     621 if not candidates:
# --> 622     raise AllTrialsFailed
#     623 losses = [float(t["result"]["loss"]) for t in candidates]
#     624 if len(losses) == 0:
#
# AllTrialsFailed:

# %%
# Find the best params looking for the lowest RMSE in MLFLOW and reuse the params here

mlflow.xgboost.autolog()

with mlflow.start_run():
    
    train = xgb.DMatrix(X_train, label=y_train)
    valid = xgb.DMatrix(X_val, label=y_val)

    best_params = {
        'learning_rate': 0.08023673823188773,
        'max_depth': 5,
        'min_child_weight': 19.53568450887438,
        'objective': 'reg:linear',
        'reg_alpha': 0.026605630217501015,
        'reg_lambda': 0.0035016901628043395,
        'seed': 42
    }
    # mlflow.log_params(best_params)

    booster = xgb.train(
        params=best_params,
        dtrain=train,
        num_boost_round=1000,
        evals=[(valid, 'validation')],
        early_stopping_rounds=50
    )

    y_pred = booster.predict(valid)
    rmse = mean_squared_error(y_val, y_pred, squared=False)
    mlflow.log_metric("rmse", rmse)

    with open("models/preprocessor.b", "wb") as f_out:
        pickle.dump(dv, f_out)
    mlflow.log_artifact("models/preprocessor.b", artifact_path="preprocessor")

    mlflow.xgboost.log_model(booster, artifact_path="models_mlflow")
# Out:
# [22:32:15] WARNING: ../src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:17541.62221
# [1]	validation-rmse:17536.57532
# [2]	validation-rmse:17532.14525
# [3]	validation-rmse:17528.75124
# [4]	validation-rmse:17525.75745
# [5]	validation-rmse:17523.29006
# [6]	validation-rmse:17521.20714
# [7]	validation-rmse:17519.57377
# [8]	validation-rmse:17518.05814
# [9]	validation-rmse:17516.88056
# [10]	validation-rmse:17516.63146
# [11]	validation-rmse:17515.95906
# [12]	validation-rmse:17514.84065
# [13]	validation-rmse:17514.49391
# [14]	validation-rmse:17513.92245
# [15]	validation-rmse:17514.47011
# [16]	validation-rmse:17513.89354
# [17]	validation-rmse:17513.59629
# [18]	validation-rmse:17514.04319
# [19]	validation-rmse:17514.25774
# [20]	validation-rmse:17514.07178
# [21]	validation-rmse:17514.16136
# [22]	validation-rmse:17513.95868
# [23]	validation-rmse:17514.47288
# [24]	validation-rmse:17514.64325
# [25]	validation-rmse:17514.62121
# [26]	validation-rmse:17514.39811
# [27]	validation-rmse:17514.41931
# [28]	validation-rmse:17514.36756
# [29]	validation-rmse:17514.36549
# [30]	validation-rmse:17514.34312
# [31]	validation-rmse:17514.63167
# [32]	validation-rmse:17515.02168
# [33]	validation-rmse:17514.92152
# [34]	validation-rmse:17514.76398
# [35]	validation-rmse:17514.57839
# [36]	validation-rmse:17514.82562
# [37]	validation-rmse:17514.71086
# [38]	validation-rmse:17515.32393
# [39]	validation-rmse:17515.20935
# [40]	validation-rmse:17515.48331
# [41]	validation-rmse:17515.49489
# [42]	validation-rmse:17515.75330
# [43]	validation-rmse:17516.76219
# [44]	validation-rmse:17516.92580
# [45]	validation-rmse:17516.56466
# [46]	validation-rmse:17516.66562
# [47]	validation-rmse:17517.07201
# [48]	validation-rmse:17517.42147
# [49]	validation-rmse:17517.62997
# [50]	validation-rmse:17517.81955
# [51]	validation-rmse:17517.82188
# [52]	validation-rmse:17517.75314
# [53]	validation-rmse:17518.28058
# [54]	validation-rmse:17518.12367
# [55]	validation-rmse:17518.64760
# [56]	validation-rmse:17518.41639
# [57]	validation-rmse:17518.56907
# [58]	validation-rmse:17518.53084
# [59]	validation-rmse:17518.76086
# [60]	validation-rmse:17518.92553
# [61]	validation-rmse:17519.35357
# [62]	validation-rmse:17520.08558
# [63]	validation-rmse:17520.25396
# [64]	validation-rmse:17520.25090
# [65]	validation-rmse:17520.33023
# [66]	validation-rmse:17520.43134
# [67]	validation-rmse:17520.55494

# %%
# Try with different ML Models
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, ExtraTreesRegressor
from sklearn.svm import LinearSVR

mlflow.sklearn.autolog() # This logs a lot of params directly in MLFLOW

for model_class in (RandomForestRegressor, GradientBoostingRegressor, ExtraTreesRegressor, LinearSVR):

    with mlflow.start_run():

        mlflow.log_param("train-data-path", "./data/train_df.parquet")
        mlflow.log_param("valid-data-path", "./data/valid_df.parquet")
        mlflow.log_artifact("models/preprocessor.b", artifact_path="preprocessor")

        mlmodel = model_class()
        mlmodel.fit(X_train, y_train)

        y_pred = mlmodel.predict(X_val)
        rmse = mean_squared_error(y_val, y_pred, squared=False)
        mlflow.log_metric("rmse", rmse)
# Out:
# /home/asurace/.local/share/virtualenvs/07-project-bZg0EPfU/lib/python3.9/site-packages/sklearn/svm/_base.py:974: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
